# %%
# %%capture
# !pip install demoji
# !pip install transformers 
# !pip install pytorch-lightning

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import demoji
# import tensorflow as tf
# import tensorflow_hub as hub
# import tensorflow_text as text

# %%
df = pd.read_csv(r'C:\Users\larsa\Documents\GitHub\NLP-Social-Media-Mining-for-Health-Monitoring\datasets\Task 2\task3_training.tsv', sep = '\t')
df_eval = pd.read_csv(r'C:\Users\larsa\Documents\GitHub\NLP-Social-Media-Mining-for-Health-Monitoring\datasets\Task 2\task3_validation.tsv', sep = '\t')
df_eval.head()
# Out:
#              tweet_id  begin   end type       extraction      drug  \
# 0  332317478170546176   28.0  37.0  ADR        allergies    avelox
# 1  347806215776116737   31.0  46.0  ADR  HURT YOUR Liver    avelox
# 2  350336129817509888   48.0  50.0  ADR               AD  baclofen
# 3  350336129817509888   88.0  93.0  ADR            focus  baclofen
# 4  332540699692130304   11.0  15.0  ADR             died     cipro
#
#                                                tweet  meddra_code  \
# 0  do you have any medication allergies? "asthma!...   10013661.0
# 1  @ashleylvivian if #avelox has hurt your liver,...   10024668.0
# 2  apparently, baclofen greatly exacerbates the "...   10003731.0
# 3  apparently, baclofen greatly exacerbates the "...   10003738.0
# 4  pt of mine died from cipro rt @ciproispoison: ...   10011906.0
#
#                   meddra_term
# 0                drug allergy
# 1                liver damage
# 2  attention deficit disorder
# 3          attention impaired
# 4                       death

# %%
#df = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/NLP-Social-Media-Mining-for-Health-Monitoring/datasets/Task 2/task3_training.tsv', sep = '\t')
#df_eval = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/NLP-Social-Media-Mining-for-Health-Monitoring/datasets/Task 2/task3_validation.tsv', sep = '\t')
#df_eval

# %%
df = df.dropna(axis=1, how='all') # drop columns that are entirely NAN
df.head()
# Out:
#              tweet_id  begin  end type extraction         drug  \
# 0  331187619096588288    NaN  NaN  NaN        NaN    ofloxacin
# 1  332227554956161024    NaN  NaN  NaN        NaN    trazodone
# 2  332448217490944000    NaN  NaN  NaN        NaN  lamotrigine
# 3  332977955754110976    NaN  NaN  NaN        NaN     cymbalta
# 4  333674203331051520    NaN  NaN  NaN        NaN     seroquel
#
#                                                tweet  meddra_code meddra_term
# 0  @seefisch:oral drugs for pyelonephritis:ciprof...          NaN         NaN
# 1  happy for wellbutrin; has similar effects as a...          NaN         NaN
# 2  @stilgarg i'm ok ty have an official diagnosis...          NaN         NaN
# 3      i'm soo depressed cymbalta couldn't help me .          NaN         NaN
# 4  time for my daily afternoon relaxation ritual ...          NaN         NaN

# %%
df_1 = df[df['type'] == "ADR"]
df_0 = df[df['type'] != "ADR"]
df_1.head()
# Out:
#               tweet_id  begin    end type   extraction      drug  \
# 27  342314998904786945   42.0   53.0  ADR  lost vision  cymbalta
# 28  342314998904786945   11.0   21.0  ADR   withdrawal  cymbalta
# 29  342322703556038657   27.0   35.0  ADR     nauseous     cipro
# 30  342349802601844737  109.0  118.0  ADR    can't cum  seroquel
# 31  342349802601844737  101.0  104.0  ADR          fat  seroquel
#
#                                                 tweet  meddra_code  \
# 27  #cymbalta withdrawal has reached a peak, lost ...   10047522.0
# 28  #cymbalta withdrawal has reached a peak, lost ...   10048010.0
# 29  i hate cipro! #antibiotic #nauseous #cf #hospi...   10028823.0
# 30  @luckystubbs reppin zoloft&amp;seroquel since ...   10021574.0
# 31  @luckystubbs reppin zoloft&amp;seroquel since ...   10047896.0
#
#             meddra_term
# 27          vision loss
# 28  withdrawal syndrome
# 29             nauseous
# 30  inability to orgasm
# 31          weight gain

# %%
def clean_tweet(tweet):
    tweet = re.sub(r"#", "", tweet, 0, re.MULTILINE)
    tweet = re.sub(r"rt", "", tweet, 0, re.MULTILINE)
    # tweet = tweet.lower()
    regex_mentions = r"@\w+"
    tweet = re.sub(regex_mentions, "@USER__", tweet, 0, re.MULTILINE)
#     regex_hash = r"(#[^\s]+)"
#     tweet = re.sub(regex_hash, "", tweet, 0, re.MULTILINE)
#     hash_matched = re.finditer(
#         regex_hash, tweet['full_text'], re.MULTILINE)
    url_regex = r"(http[^\s]+)"
    tweet = re.sub(url_regex, "", tweet, 0, re.MULTILINE)
    # special_char_re = r"[^(?u)\w]+"
    # tweet = re.sub(special_char_re, " ", tweet, 0, re.MULTILINE)
    return tweet

# %%
def emoji2Text(text):
    emojiTranslate = { # top 19 emojis used
    '😂': 'laughing',
    '😩': 'distraught',
    '😳': 'surprise',
    '💊': 'medication',
    '😭': 'laughing crying',
    '😒': 'disapproving',
    '😴': 'bored tired',
    '😷': 'sick',
    '😔': 'remorseful',
    '👌': 'correct',
    '👍': 'approve',
    '😫': 'weary',
    '🙌': 'celebration',
    '😏': 'smug',
    '😊': 'happy',
    '😖': 'confounded',
    '💤': 'tired',
    '😁': 'cheerful',
    '❤️': 'love'}

    for word, e in emojiTranslate.items():
        text = text.replace(word.lower(), e)
    
    text = text.lstrip().rstrip()
    
    return text

# %%
def remove_emojis(text):
    # emoticons_happy = list([
    #     ':-)', ':)', ';)', ':o)', ':]', ':3', ':c)', ':>', '=]', '8)', '=)', ':}',
    #     ':^)', ':-D', ':D', '8-D', '8D', 'x-D', 'xD', 'X-D', 'XD', '=-D', '=D',
    #     '=-3', '=3', ':-))', ":'-)", ":')", ':*', ':^*', '>:P', ':-P', ':P', 'X-P',
    #     'x-p', 'xp', 'XP', ':-p', ':p', '=p', ':-b', ':b', '>:)', '>;)', '>:-)',
    #     '<3'
    # ])
    # emoticons_sad = list([
    #     ':L', ':-/', '>:/', ':S', '>:[', ':@', ':-(', ':[', ':-||', '=L', ':<',
    #     ':-[', ':-<', '=\\', '=/', '>:(', ':(', '>.<', ":'-(", ":'(", ':\\', ':-c',
    #     ':c', ':{', '>:\\', ';('
    # ])
    all_emoticons = [':/',':l',':-)','-.-',':::---))))','&lt;',":'(",'-_-',':)','xx','xxx',';-)',
                     ':(',':-/',':)', ';)', ':o)', ':]', ':3', ':c)', ':>', '=]', '8)', '=)', ':}',
                     ':^)', ':-D', ':D', '8-D', '8D', 'x-D', 'xD', 'X-D', 'XD', '=-D', '=D','d:',':-l','&lt;3',
                     '=-3', '=3', ':-))', ":'-)", ":')", ':*', ':^*', '>:P', ':-P', ':P', 'X-P',':|','o_o',';)',
                     'x-p', 'xp', 'XP', ':-p', ':p', '=p', ':-b', ':b', '>:)', '>;)', '>:-)',':-0','-__-',':(((',
                     '<3'':L', ':-/', '>:/', ':S', '>:[', ':@', ':-(', ':[', ':-||', '=L', ':<',
                     ':-[', ':-<', '=/', '>:(', ':(', '>.<', ":'-(", ":'(",  ':-c',':c', ':{',  ';(', "=\\", ">:\\", ':\\']

    emojis = list(demoji.findall(text).keys())
    clean_text = demoji.replace(text, '')

    for emo in all_emoticons:
        if (emo in clean_text):
            clean_text = clean_text.replace(emo, '')
            emojis.append(emo)

    clean_text = clean_text.replace('\n', '', -1)
    
    # using regex to remove urls
    # regex_url = r"https:(.*)[A-Za-z0-9]"
    # clean_text = re.sub(regex_url, '', clean_text, 0, re.MULTILINE)

    return clean_text #, emojis

# %%
df['tweet'] = df['tweet'].map(lambda tweet: clean_tweet(remove_emojis(emoji2Text(tweet))))
df_eval['tweet'] = df_eval['tweet'].map(lambda tweet: clean_tweet(remove_emojis(emoji2Text(tweet))))

# %%
df_ADR = df.loc[df['type'] == 'ADR']

# %%
df
# Out:
#                 tweet_id  begin    end type           extraction         drug  \
# 0     331187619096588288    NaN    NaN  NaN                  NaN    ofloxacin
# 1     332227554956161024    NaN    NaN  NaN                  NaN    trazodone
# 2     332448217490944000    NaN    NaN  NaN                  NaN  lamotrigine
# 3     332977955754110976    NaN    NaN  NaN                  NaN     cymbalta
# 4     333674203331051520    NaN    NaN  NaN                  NaN     seroquel
# ...                  ...    ...    ...  ...                  ...          ...
# 2241  347921687729299456    NaN    NaN  NaN                  NaN          NaN
# 2242  348383854089871360   72.0   91.0  ADR  gain so much weight      zyprexa
# 2243  348595096352075776    NaN    NaN  NaN                  NaN      zyprexa
# 2244  349181683293102080   99.0  117.0  ADR   increase my weight      zyprexa
# 2245  358295661797572610   14.0   27.0  ADR        gained 30 lbs      zyprexa
#
#                                                   tweet  meddra_code  \
# 0     @USER__:oral drugs for pyelonephritisiprofloxa...          NaN
# 1     happy for wellbutrin; has similar effects as a...          NaN
# 2     @USER__ i'm ok ty have an official diagnosis o...          NaN
# 3         i'm soo depressed cymbalta couldn't help me .          NaN
# 4     time for my daily afternoon relaxation ritual ...          NaN
# ...                                                 ...          ...
# 2241  i will admit that most people would agree zypr...          NaN
# 2242  that zyprexa really makes your vocal chords ma...   10047896.0
# 2243  @USER__ i'm hoping that i get on the zyprexa. ...          NaN
# 2244  i'm so fine today. increasing zyprexa,my condi...   10047898.0
# 2245  i might have gained 30 lbs in 6 weeks on zypre...   10047896.0
#
#           meddra_term
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 2241              NaN
# 2242      weight gain
# 2243              NaN
# 2244  weight increase
# 2245      weight gain
#
# [2246 rows x 9 columns]

# %%
TRAIN_DATA = []

for index, row in df_ADR.iterrows():
    tweet, begin, end, ex = row['tweet'], int(row['begin']), int(row['end']), row['extraction']

    TRAIN_DATA.append((tweet,{'entities':[(begin,end,ex)]}))

# %%
df_eval.head()
# Out:
#              tweet_id  begin   end type       extraction      drug  \
# 0  332317478170546176   28.0  37.0  ADR        allergies    avelox
# 1  347806215776116737   31.0  46.0  ADR  HURT YOUR Liver    avelox
# 2  350336129817509888   48.0  50.0  ADR               AD  baclofen
# 3  350336129817509888   88.0  93.0  ADR            focus  baclofen
# 4  332540699692130304   11.0  15.0  ADR             died     cipro
#
#                                                tweet  meddra_code  \
# 0  do you have any medication allergies? "asthma!...   10013661.0
# 1  @USER__ if avelox has hu your liver, avoid tyl...   10024668.0
# 2  apparently, baclofen greatly exacerbates the "...   10003731.0
# 3  apparently, baclofen greatly exacerbates the "...   10003738.0
# 4  pt of mine died from cipro  @USER__: @USER__ i...   10011906.0
#
#                   meddra_term
# 0                drug allergy
# 1                liver damage
# 2  attention deficit disorder
# 3          attention impaired
# 4                       death

# %%
TRAIN_DATA
# Out:
# [('cymbalta withdrawal has reached a peak, lost vision and almost crashed my car from a brain zap. thanks a zillion elililly bigpharma',
#   {'entities': [(42, 53, 'lost vision')]}),
#  ('cymbalta withdrawal has reached a peak, lost vision and almost crashed my car from a brain zap. thanks a zillion elililly bigpharma',
#   {'entities': [(11, 21, 'withdrawal')]}),
#  ('i hate cipro! antibiotic nauseous cf hospitallife cysticfibrosis',
#   {'entities': [(27, 35, 'nauseous')]}),
#  ("@USER__ reppin zoloft&amp;seroquel since last november. i'm hella gainin weight too awesome i'm fat and can't cum i own",
#   {'entities': [(109, 118, "can't cum")]}),
#  ("@USER__ reppin zoloft&amp;seroquel since last november. i'm hella gainin weight too awesome i'm fat and can't cum i own",
#   {'entities': [(101, 104, 'fat')]}),
#  ("@USER__ reppin zoloft&amp;seroquel since last november. i'm hella gainin weight too awesome i'm fat and can't cum i own",
#   {'entities': [(71, 84, 'gainin weight')]}),
#  ("i've had a trazodone headache all day. i heard they go away within a week. hopeso iactuallyslept",
#   {'entities': [(21, 29, 'headache')]}),
#  ("i've had ocd symptoms like that for a while but seems like the seroquel exacerbates things and now this. ",
#   {'entities': [(72, 83, 'exacerbates')]}),
#  ("i finally had an appetite, made food, gone. humira why won't you let me eat",
#   {'entities': [(56, 76, "WON'T YOU LET ME EAT")]}),
#  ("@USER__ i don't care if they are toxic haha putting the cipro drops in is essentially equivalent to toure oww",
#   {'entities': [(116, 119, 'oww')]}),
#  ("@USER__ i don't care if they are toxic haha putting the cipro drops in is essentially equivalent to toure oww",
#   {'entities': [(40, 45, 'toxic')]}),
#  ("@USER__ i don't care if they are toxic haha putting the cipro drops in is essentially equivalent to toure oww",
#   {'entities': [(93, 114, 'equivalent to torture')]}),
#  ('@USER__ dizzy, out if it and confused on the drugs.  upping the baclofen slowly now as i seem better on these.',
#   {'entities': [(36, 44, 'confused')]}),
#  ('@USER__ dizzy, out if it and confused on the drugs.  upping the baclofen slowly now as i seem better on these.',
#   {'entities': [(15, 20, 'dizzy')]}),
#  ('@USER__ dizzy, out if it and confused on the drugs.  upping the baclofen slowly now as i seem better on these.',
#   {'entities': [(22, 31, 'out if it')]}),
#  ('@USER__ cause humira gives me a lot of rashes and like most of these drugs.. skin sensitivity happens',
#   {'entities': [(81, 97, 'Skin sensitivity')]}),
#  ('@USER__ cause humira gives me a lot of rashes and like most of these drugs.. skin sensitivity happens',
#   {'entities': [(43, 49, 'rashes')]}),
#  ("@USER__ @USER__ @USER__ *buts in* you don't wanna miss venlafaxine no no it made me so wonky missing one day! ouch",
#   {'entities': [(110, 115, 'wonky')]}),
#  ('?@USER__: my vyvanse makes me nocturnal ???',
#   {'entities': [(34, 43, 'nocturnal')]}),
#  ("i'd gladly trade the mtx  headache for humira but after 5 months i still don't have the prescription. i function through vitamins &amp; motrin",
#   {'entities': [(27, 35, 'headache')]}),
#  ("thank god i was born with so much hair; i wouldn't been balm by now. crohnsproblems teamibd hairloss humira chronic illness gratitude",
#   {'entities': [(56, 60, 'balm')]}),
#  ("thank god i was born with so much hair; i wouldn't been balm by now. crohnsproblems teamibd hairloss humira chronic illness gratitude",
#   {'entities': [(95, 103, 'hairloss')]}),
#  ('vyvanse makes me having the sleeping schedule of a vampire.',
#   {'entities': [(28, 58, 'sleeping schedule of a vampire')]}),
#  ('1/2 vitamin d malsorption and damaged photosynthesis of sun shine in to vitamin d from levaquin toxicity leading to calcium problems.',
#   {'entities': [(116, 132, 'calcium problems')]}),
#  ('1/2 vitamin d malsorption and damaged photosynthesis of sun shine in to vitamin d from levaquin toxicity leading to calcium problems.',
#   {'entities': [(4, 25, 'Vitamin D malsorption')]}),
#  ('but still dr. maria jasinskas was right &amp; would have been if not for pharmacy; she said, "you know sometimes vyvanse can make you depressed"',
#   {'entities': [(136, 145, 'depressed')]}),
#  ('@USER__ quetiapine was horrific for me in relation to wait gain. such a horror story. but the weight will come off one day at a time.',
#   {'entities': [(59, 68, 'wait gain')]}),
#  ('@USER__ quetiapine was horrific for me in relation to wait gain. such a horror story. but the weight will come off one day at a time.',
#   {'entities': [(99, 105, 'weight')]}),
#  ("@USER__ what problems did you have with humira, if you don't mind me asking. i tried infliximab it destroyed my liver.",
#   {'entities': [(104, 122, 'destroyed my liver')]}),
#  ('@USER__ @USER__ me too, remicade for a year, humira, and had an allergic reaction to cimzia, almost killed me in november.',
#   {'entities': [(79, 96, 'allergic reaction')]}),
#  ('@USER__ @USER__ me too, remicade for a year, humira, and had an allergic reaction to cimzia, almost killed me in november.',
#   {'entities': [(108, 124, 'almost killed me')]}),
#  ('@USER__ @USER__ lexapro gave me the worst mixed episodes. i have some instability with pristiq but i can manage it ok.',
#   {'entities': [(56, 70, 'mixed episodes')]}),
#  ('@USER__ (( when i used to take trazodone to sleep, people would make me stay up after i took it so they could watch me be high ))',
#   {'entities': [(131, 135, 'high')]}),
#  ('im having paroxetine withdrawals but thats ok cuz i still aint takin no moe fuck behavioral health ill be iight',
#   {'entities': [(21, 32, 'WITHDRAWALS')]}),
#  ('almost blew out my arms &amp; heels @ work. they hu like hell. &amp; the pain is spreading, damned cipro.',
#   {'entities': [(76, 80, 'pain')]}),
#  ('almost blew out my arms &amp; heels @ work. they hu like hell. &amp; the pain is spreading, damned cipro.',
#   {'entities': [(31, 36, 'heels')]}),
#  ('almost blew out my arms &amp; heels @ work. they hu like hell. &amp; the pain is spreading, damned cipro.',
#   {'entities': [(50, 54, 'hurt')]}),
#  ('almost blew out my arms &amp; heels @ work. they hu like hell. &amp; the pain is spreading, damned cipro.',
#   {'entities': [(8, 24, 'blew out my arms')]}),
#  ('adderall makes me vomit and vyvanse gives me migraines.. the struggle',
#   {'entities': [(45, 54, 'migraines')]}),
#  ('adderall makes me vomit and vyvanse gives me migraines.. the struggle',
#   {'entities': [(18, 23, 'vomit')]}),
#  ("the quetiapine is kicking in. bizarre thoughts tonight. tempted to take the whole lot. i won't - don't worry people. just odd thoughts.",
#   {'entities': [(31, 47, 'Bizarre thoughts')]}),
#  ("i'm always irritated on vyvanse because people can't think as fast as i can. it's like every conversation is with someone at a nursing home",
#   {'entities': [(47, 66, "can't think as fast")]}),
#  ("i'm always irritated on vyvanse because people can't think as fast as i can. it's like every conversation is with someone at a nursing home",
#   {'entities': [(11, 20, 'irritated')]}),
#  ('@USER__ @USER__ try something like wellbutrin - there are many better than zoloft (zombie-loft) and paxil for anxiety imo',
#   {'entities': [(86, 92, 'zombie')]}),
#  ("i fell asleep and woke back up again. trying a quaer of a seroquel instead of half this time. i'd like to get out of bed tomorrow.",
#   {'entities': [(108, 123, 'get out of bed ')]}),
#  ("does anyone on tysabri get flu iike symptoms, aches and pains, shivers a sweats i seem to get it about a week or so after i've had infusion",
#   {'entities': [(48, 63, 'aches and pains')]}),
#  ("does anyone on tysabri get flu iike symptoms, aches and pains, shivers a sweats i seem to get it about a week or so after i've had infusion",
#   {'entities': [(29, 46, 'flu Iike symptoms')]}),
#  ("does anyone on tysabri get flu iike symptoms, aches and pains, shivers a sweats i seem to get it about a week or so after i've had infusion",
#   {'entities': [(65, 72, 'shivers')]}),
#  ("does anyone on tysabri get flu iike symptoms, aches and pains, shivers a sweats i seem to get it about a week or so after i've had infusion",
#   {'entities': [(75, 81, 'sweats')]}),
#  (' @USER__: if this fuckin emt looks at me one more time hes gonna feel the wrath of my vyvanse rage',
#   {'entities': [(101, 105, 'rage')]}),
#  ('21.55 rivaroxaban diary day 8. aches easing, back pain easing. swollen lower legs like fluid retention. i take 20mg. furosemide every a.m.',
#   {'entities': [(32, 37, 'Aches')]}),
#  ('21.55 rivaroxaban diary day 8. aches easing, back pain easing. swollen lower legs like fluid retention. i take 20mg. furosemide every a.m.',
#   {'entities': [(46, 55, 'back pain')]}),
#  ('21.55 rivaroxaban diary day 8. aches easing, back pain easing. swollen lower legs like fluid retention. i take 20mg. furosemide every a.m.',
#   {'entities': [(88, 103, 'fluid retention')]}),
#  ('21.55 rivaroxaban diary day 8. aches easing, back pain easing. swollen lower legs like fluid retention. i take 20mg. furosemide every a.m.',
#   {'entities': [(64, 82, 'Swollen lower legs')]}),
#  ('@USER__ @USER__ comedown is hell. when i went cold turkey from effexor it was about two weeks before the zap noises stopped',
#   {'entities': [(31, 47, 'comedown is hell')]}),
#  ('@USER__ @USER__ comedown is hell. when i went cold turkey from effexor it was about two weeks before the zap noises stopped',
#   {'entities': [(120, 130, 'zap noises')]}),
#  ('my effexor has left me with the inability to cry. i was dry eyed watching "into the wild" and even one of those sarah mclachlan commercials',
#   {'entities': [(57, 65, 'dry eyed')]}),
#  ('my effexor has left me with the inability to cry. i was dry eyed watching "into the wild" and even one of those sarah mclachlan commercials',
#   {'entities': [(33, 49, 'inability to cry')]}),
#  ("i hate how vyvanse makes me over think everything and it makes me angry about things that i shouldn't even be angry about",
#   {'entities': [(66, 71, 'angry')]}),
#  ("i hate how vyvanse makes me over think everything and it makes me angry about things that i shouldn't even be angry about",
#   {'entities': [(28, 38, 'over think')]}),
#  ('too tired to function right now, thanks humira. naptime ??????',
#   {'entities': [(50, 57, 'naptime')]}),
#  ('too tired to function right now, thanks humira. naptime ??????',
#   {'entities': [(5, 10, 'tired')]}),
#  (' @USER__: almost blew out my arms &amp; heels @ work. they hu like hell. &amp; the pain is spreading, damned cipro.',
#   {'entities': [(95, 99, 'pain')]}),
#  (' @USER__: almost blew out my arms &amp; heels @ work. they hu like hell. &amp; the pain is spreading, damned cipro.',
#   {'entities': [(50, 55, 'heels')]}),
#  (' @USER__: almost blew out my arms &amp; heels @ work. they hu like hell. &amp; the pain is spreading, damned cipro.',
#   {'entities': [(69, 73, 'hurt')]}),
#  (' @USER__: almost blew out my arms &amp; heels @ work. they hu like hell. &amp; the pain is spreading, damned cipro.',
#   {'entities': [(27, 43, 'blew out my arms')]}),
#  ('fuckin wired! not sleeping tonight. vyvanse whatdoido yuuuuup',
#   {'entities': [(14, 26, 'Not sleeping')]}),
#  ('fuckin wired! not sleeping tonight. vyvanse whatdoido yuuuuup',
#   {'entities': [(7, 12, 'wired')]}),
#  ('had 2 quit job: tendons in lots of pain,  almost ruptured, hands barely usable now. damned cipro.',
#   {'entities': [(60, 79, 'hands barely usable')]}),
#  ('had 2 quit job: tendons in lots of pain,  almost ruptured, hands barely usable now. damned cipro.',
#   {'entities': [(16, 40, ' tendons in lots of pain')]}),
#  ("no med orders til effexor is fully exited. still having brain shivers, but mostly when i don't eat. effexor withdrawal depression",
#   {'entities': [(57, 70, 'brain shivers')]}),
#  ("no med orders til effexor is fully exited. still having brain shivers, but mostly when i don't eat. effexor withdrawal depression",
#   {'entities': [(111, 121, 'withdrawal')]}),
#  ('@USER__ did i read in a blog post that you took venlafaxine? i am on 300mg and if i forget it for one day i can barely function the next',
#   {'entities': [(116, 131, 'barely function')]}),
#  ('restless arms &amp; legs! blood quetiapine ',
#   {'entities': [(0, 13, 'Restless arms')]}),
#  ('restless arms &amp; legs! blood quetiapine ',
#   {'entities': [(0, 24, 'restless arms &amp; legs')]}),
#  ("i've been sleeping most of my day away thanks to my humira shot. some days i feel like just giving up. sick&amp;tired",
#   {'entities': [(10, 18, 'sleeping')]}),
#  ("at my old weight my bmi was 18.4. i hate seroquel and prozac and my new pill, i don't eat but still gain weight.",
#   {'entities': [(101, 112, 'gain weight')]}),
#  ("@USER__ glad to here it's keppra over the others. lamictal made me a zombie. first seizure is a bitch eh?",
#   {'entities': [(74, 80, 'zombie')]}),
#  (' @USER__: @USER__ even w/ humira: ab pain, cramps,nausea,vomitting, skin&amp;joint problems, ulcers in mouth&amp;fatique uclaibdnurses2013',
#   {'entities': [(44, 51, 'ab pain')]}),
#  (' @USER__: @USER__ even w/ humira: ab pain, cramps,nausea,vomitting, skin&amp;joint problems, ulcers in mouth&amp;fatique uclaibdnurses2013',
#   {'entities': [(53, 59, 'cramps')]}),
#  (' @USER__: @USER__ even w/ humira: ab pain, cramps,nausea,vomitting, skin&amp;joint problems, ulcers in mouth&amp;fatique uclaibdnurses2013',
#   {'entities': [(123, 130, 'fatique')]}),
#  (' @USER__: @USER__ even w/ humira: ab pain, cramps,nausea,vomitting, skin&amp;joint problems, ulcers in mouth&amp;fatique uclaibdnurses2013',
#   {'entities': [(87, 101, 'joint problems')]}),
#  (' @USER__: @USER__ even w/ humira: ab pain, cramps,nausea,vomitting, skin&amp;joint problems, ulcers in mouth&amp;fatique uclaibdnurses2013',
#   {'entities': [(60, 66, 'nausea')]}),
#  (' @USER__: @USER__ even w/ humira: ab pain, cramps,nausea,vomitting, skin&amp;joint problems, ulcers in mouth&amp;fatique uclaibdnurses2013',
#   {'entities': [(78, 82, 'skin')]}),
#  (' @USER__: @USER__ even w/ humira: ab pain, cramps,nausea,vomitting, skin&amp;joint problems, ulcers in mouth&amp;fatique uclaibdnurses2013',
#   {'entities': [(103, 118, 'ulcers in mouth')]}),
#  (' @USER__: @USER__ even w/ humira: ab pain, cramps,nausea,vomitting, skin&amp;joint problems, ulcers in mouth&amp;fatique uclaibdnurses2013',
#   {'entities': [(67, 76, 'vomitting')]}),
#  ('@USER__ they probably would have offered me the full anti psychotic menu had i not reacted badly to seroquel handy bonus',
#   {'entities': [(85, 98, 'reacted badly')]}),
#  ('@USER__ i was prescribed victoza for obesity in july 2010. i have been ill ever since. evil drug diabetes',
#   {'entities': [(77, 80, 'ill')]}),
#  (' @USER__: vyvanse, commonly known as ocd in a pill.',
#   {'entities': [(45, 48, 'OCD')]}),
#  ("i'm having to pee way too much this drive.. drinking too much water. fuck you 70mg vyvanse and your ability to dehydrate the fuck out of me.",
#   {'entities': [(111, 120, 'dehydrate')]}),
#  ("i'm having to pee way too much this drive.. drinking too much water. fuck you 70mg vyvanse and your ability to dehydrate the fuck out of me.",
#   {'entities': [(14, 30, 'pee way too much')]}),
#  ('this rant could be paxil withdrawl...or delayed divorce rage.',
#   {'entities': [(5, 9, 'rant')]}),
#  ('this rant could be paxil withdrawl...or delayed divorce rage.',
#   {'entities': [(26, 35, 'withdrawl')]}),
#  ('also, yay addiction. it\'s drugs i need for living, but it\'s still dependance. every time i get a "paxil headache" i realize this. oh well.',
#   {'entities': [(11, 20, 'addiction')]}),
#  ('also, yay addiction. it\'s drugs i need for living, but it\'s still dependance. every time i get a "paxil headache" i realize this. oh well.',
#   {'entities': [(67, 77, 'dependance')]}),
#  ('also, yay addiction. it\'s drugs i need for living, but it\'s still dependance. every time i get a "paxil headache" i realize this. oh well.',
#   {'entities': [(106, 114, 'headache')]}),
#  ("gotta find an alternative to vyvanse, asap. i'd rather be sleepy &amp; happy, than ale &amp; depressed!",
#   {'entities': [(96, 105, 'depressed')]}),
#  ('@USER__ yeh same bk felt like sumo wrestler on it all time  think its f****ed me 4life  ironic as humira is used to treat aheritis',
#   {'entities': [(24, 47, 'felt like sumo wrestler')]}),
#  ("okay i took the seroquel and i am resisting the urge to vomit it up i feel disgusting but oh well good times good vibes don't be sad",
#   {'entities': [(70, 85, 'feel disgusting')]}),
#  ("okay i took the seroquel and i am resisting the urge to vomit it up i feel disgusting but oh well good times good vibes don't be sad",
#   {'entities': [(48, 61, 'urge to vomit')]}),
#  ("why not to take vyvanse late in the day: i just cleaned my entire kitchen. it's 3am. addproblems @USER__",
#   {'entities': [(48, 73, 'cleaned my entire kitchen')]}),
#  ("why not to take vyvanse late in the day: i just cleaned my entire kitchen. it's 3am. addproblems @USER__",
#   {'entities': [(80, 83, '3am')]}),
#  ("@USER__ missing a day of meds is never fun. i get migraines if i don't get my effexor. do you just get super tired?",
#   {'entities': [(57, 66, 'migraines')]}),
#  ("@USER__ missing a day of meds is never fun. i get migraines if i don't get my effexor. do you just get super tired?",
#   {'entities': [(116, 121, 'tired')]}),
#  ("i'm high af on vyvanse.", {'entities': [(4, 8, 'high')]}),
#  ('@USER__ @USER__ re victoza i was prescribed this in 2010 for obesity. caused pancreatitis and digestive problems ever since',
#   {'entities': [(107, 125, 'digestive problems')]}),
#  ('@USER__ @USER__ re victoza i was prescribed this in 2010 for obesity. caused pancreatitis and digestive problems ever since',
#   {'entities': [(90, 102, 'pancreatitis')]}),
#  ('@USER__ when are you going to do true life: i am addicted to vyvanse?',
#   {'entities': [(46, 54, 'addicted')]}),
#  ('09.26 day 12 rivaroxaban diary:  headache, right shoulder and neck ache, lower back pain, weak knees, limping when walking.taken paracetamol',
#   {'entities': [(34, 42, 'headache')]}),
#  ('09.26 day 12 rivaroxaban diary:  headache, right shoulder and neck ache, lower back pain, weak knees, limping when walking.taken paracetamol',
#   {'entities': [(74, 89, 'lower back pain')]}),
#  ('09.26 day 12 rivaroxaban diary:  headache, right shoulder and neck ache, lower back pain, weak knees, limping when walking.taken paracetamol',
#   {'entities': [(63, 72, 'neck ache')]}),
#  ('09.26 day 12 rivaroxaban diary:  headache, right shoulder and neck ache, lower back pain, weak knees, limping when walking.taken paracetamol',
#   {'entities': [(50, 58, 'shoulder')]}),
#  ('09.26 day 12 rivaroxaban diary:  headache, right shoulder and neck ache, lower back pain, weak knees, limping when walking.taken paracetamol',
#   {'entities': [(91, 101, 'weak knees')]}),
#  ('09.26 day 12 rivaroxaban diary:  headache, right shoulder and neck ache, lower back pain, weak knees, limping when walking.taken paracetamol',
#   {'entities': [(103, 110, 'limping')]}),
#  ('get asked if i have tourettes. nope. just vyvanse twitchy @USER__',
#   {'entities': [(20, 29, 'tourettes')]}),
#  ('get asked if i have tourettes. nope. just vyvanse twitchy @USER__',
#   {'entities': [(51, 58, 'Twitchy')]}),
#  ("i don't know whether my vyvanse caused my caffeine addiction or caffeine caused my vyvanse addiction.",
#   {'entities': [(91, 100, 'addiction')]}),
#  (" @USER__: i don't know whether my vyvanse caused my caffeine addiction or caffeine caused my vyvanse addiction.",
#   {'entities': [(68, 77, 'addiction')]}),
#  ('my house smells of bacon &amp; seroquel is making me so hungry i want to tear my own face off &amp; eat it or cry or maybe both at once.',
#   {'entities': [(110, 113, 'cry')]}),
#  ('my house smells of bacon &amp; seroquel is making me so hungry i want to tear my own face off &amp; eat it or cry or maybe both at once.',
#   {'entities': [(56, 62, 'hungry')]}),
#  ('my house smells of bacon &amp; seroquel is making me so hungry i want to tear my own face off &amp; eat it or cry or maybe both at once.',
#   {'entities': [(73, 106, 'tear my own face off &amp; eat it')]}),
#  ("@USER__ yup quetiapine. the normal dose at night whacks me out. i'd have been asleep til friday on double",
#   {'entities': [(51, 64, 'whacks me out')]}),
#  ("@USER__ yup quetiapine. the normal dose at night whacks me out. i'd have been asleep til friday on double",
#   {'entities': [(80, 86, 'asleep')]}),
#  ("i'm not sure if excedrin is the right way for me to go for my tmj headaches. vyvanse + caffeine is pretty rough. ideas?",
#   {'entities': [(66, 75, 'headaches')]}),
#  ("i'm not sure if excedrin is the right way for me to go for my tmj headaches. vyvanse + caffeine is pretty rough. ideas?",
#   {'entities': [(62, 65, 'TMJ')]}),
#  ('13.08 day 13 rivaroxaban diary.  pracetamol has taken away most of the aches, but still have lower back ache and weak knees.',
#   {'entities': [(72, 77, 'aches')]}),
#  ('13.08 day 13 rivaroxaban diary.  pracetamol has taken away most of the aches, but still have lower back ache and weak knees.',
#   {'entities': [(94, 109, 'lower back ache')]}),
#  ('13.08 day 13 rivaroxaban diary.  pracetamol has taken away most of the aches, but still have lower back ache and weak knees.',
#   {'entities': [(114, 124, 'weak knees')]}),
#  ('cant cope coming off venlafaxine feel like iv got a hangover mixed with flu symptoms. total nausea &amp; i cant keep still. please hurry &amp; pass',
#   {'entities': [(10, 20, 'coming off')]}),
#  ('cant cope coming off venlafaxine feel like iv got a hangover mixed with flu symptoms. total nausea &amp; i cant keep still. please hurry &amp; pass',
#   {'entities': [(73, 85, 'flu symptoms')]}),
#  ('cant cope coming off venlafaxine feel like iv got a hangover mixed with flu symptoms. total nausea &amp; i cant keep still. please hurry &amp; pass',
#   {'entities': [(53, 61, 'hangover')]}),
#  ('cant cope coming off venlafaxine feel like iv got a hangover mixed with flu symptoms. total nausea &amp; i cant keep still. please hurry &amp; pass',
#   {'entities': [(93, 99, 'nausea')]}),
#  ('cant cope coming off venlafaxine feel like iv got a hangover mixed with flu symptoms. total nausea &amp; i cant keep still. please hurry &amp; pass',
#   {'entities': [(108, 123, 'cant keep still')]}),
#  ("@USER__ i don't know that one, but metho made me sick  everyday i took it. i had to stop. enbrel has worked wonders for me .. so far",
#   {'entities': [(54, 59, 'sick ')]}),
#  ("@USER__ i'm allergic to enbrel  bad reaction",
#   {'entities': [(14, 22, 'allergic')]}),
#  (" @USER__ @USER__ i don't know that one, but metho made me sick  everyday i took it. i had to stop. enbrel has worked wonders for m?",
#   {'entities': [(68, 72, 'sick')]}),
#  ('just wondering where the side effect of hating the world is stated on vyvanse adveisements?',
#   {'entities': [(40, 56, 'hating the world')]}),
#  ('this lamictal shit ain\'t cuttin the mustard; any "mood stabilizers" that don\'t steal your soul &amp; make u a bloated zombie a la britney?',
#   {'entities': [(113, 120, 'bloated')]}),
#  ('this lamictal shit ain\'t cuttin the mustard; any "mood stabilizers" that don\'t steal your soul &amp; make u a bloated zombie a la britney?',
#   {'entities': [(82, 97, 'steal your soul')]}),
#  ('this lamictal shit ain\'t cuttin the mustard; any "mood stabilizers" that don\'t steal your soul &amp; make u a bloated zombie a la britney?',
#   {'entities': [(121, 127, 'zombie')]}),
#  ('@USER__ ssris were great for me for ages, not working as well now. thus seroquel.  i?m also on clonazepam, makes me sleepy too.',
#   {'entities': [(52, 71, 'not working as well')]}),
#  ('@USER__ ssris were great for me for ages, not working as well now. thus seroquel.  i?m also on clonazepam, makes me sleepy too.',
#   {'entities': [(126, 132, 'sleepy')]}),
#  ('@USER__ cipro and flagyl are the absolute worst. like taking rat poison.',
#   {'entities': [(56, 78, 'like taking rat poison')]}),
#  ('@USER__ @USER__ i tried baclofen, another common muscle relaxer, and had too many side-effects from it, including worsening pain.',
#   {'entities': [(123, 137, 'worsening pain')]}),
#  ('@USER__ the effexor may have been pushing me toward hypomania, so we are trying just an ssri, then see if a mood stabilizer is needed.',
#   {'entities': [(54, 63, 'hypomania')]}),
#  ("seroquel left me with sleep paralysis. abilify left me with occasional muscle spasms. i've been off of both for nearly a decade.",
#   {'entities': [(71, 84, 'muscle spasms')]}),
#  ("seroquel left me with sleep paralysis. abilify left me with occasional muscle spasms. i've been off of both for nearly a decade.",
#   {'entities': [(22, 37, 'sleep paralysis')]}),
#  ('@USER__ ugh the olanzapine makes me so tired ',
#   {'entities': [(47, 52, 'tired')]}),
#  ('@USER__ @USER__ when i weaned myself off paxil, slower than recommended, my blood pressure dropped so bad i couldn?t walk for a week.',
#   {'entities': [(84, 106, 'blood pressure dropped')]}),
#  ('@USER__ @USER__ when i weaned myself off paxil, slower than recommended, my blood pressure dropped so bad i couldn?t walk for a week.',
#   {'entities': [(116, 129, 'couldn?t walk')]}),
#  ("gimme one reason why i shouldn't have sex drive / libido. i accept this as a pa of withdrawal symptoms from venlafaxine. :o",
#   {'entities': [(85, 95, 'withdrawal')]}),
#  ("gimme one reason why i shouldn't have sex drive / libido. i accept this as a pa of withdrawal symptoms from venlafaxine. :o",
#   {'entities': [(50, 56, 'libido')]}),
#  ("gimme one reason why i shouldn't have sex drive / libido. i accept this as a pa of withdrawal symptoms from venlafaxine. :o",
#   {'entities': [(38, 47, 'sex drive')]}),
#  ("i called for my effexor refill on wednesday. i was out. it's sunday and i can't stop screaming and crying",
#   {'entities': [(99, 105, 'crying')]}),
#  ("i called for my effexor refill on wednesday. i was out. it's sunday and i can't stop screaming and crying",
#   {'entities': [(85, 94, 'screaming')]}),
#  ("arms stil hu. cipro to tendons is like a razor to rope: cut it paway through, makes it weaker &amp; won't heal ever. damned cipro.",
#   {'entities': [(1, 15, 'arms stil hurt')]}),
#  ("arms stil hu. cipro to tendons is like a razor to rope: cut it paway through, makes it weaker &amp; won't heal ever. damned cipro.",
#   {'entities': [(26, 57, 'tendons is like a razor to rope')]}),
#  ("arms stil hu. cipro to tendons is like a razor to rope: cut it paway through, makes it weaker &amp; won't heal ever. damned cipro.",
#   {'entities': [(92, 98, 'weaker')]}),
#  ("arms stil hu. cipro to tendons is like a razor to rope: cut it paway through, makes it weaker &amp; won't heal ever. damned cipro.",
#   {'entities': [(105, 115, "won't heal")]}),
#  ('eurgh! last time i was this tired, i was on a four day antidepressant cocktail binge.  seroxat seraline fluoxitine lithium',
#   {'entities': [(29, 34, 'tired')]}),
#  ("rivaroxaban 2/2 lower back pain. not very pc but am crippled by this drug. taking more paracetamols. must ring for 'phone consultation.",
#   {'entities': [(16, 31, 'lower back pain')]}),
#  ("rivaroxaban 2/2 lower back pain. not very pc but am crippled by this drug. taking more paracetamols. must ring for 'phone consultation.",
#   {'entities': [(52, 60, 'crippled')]}),
#  ('@USER__ i was on enbrel for 8 years have since developed neuro problems (ataxia) wish id never taken it side effects not woh risks',
#   {'entities': [(80, 86, 'ataxia')]}),
#  ('@USER__ i was on enbrel for 8 years have since developed neuro problems (ataxia) wish id never taken it side effects not woh risks',
#   {'entities': [(64, 78, 'neuro problems')]}),
#  ('@USER__ i essentially felt nothing on them. great for anxiety, bad for living. coming off klonopin and paxil was hell though.',
#   {'entities': [(82, 120, 'coming off klonopin and paxil was hell')]}),
#  ('@USER__ i essentially felt nothing on them. great for anxiety, bad for living. coming off klonopin and paxil was hell though.',
#   {'entities': [(25, 37, 'felt nothing')]}),
#  ('@USER__ well i?m taking it with a mood stabilizer (lamictal). i can?t take anti-depressants by themselves-triggers my rapid cycling',
#   {'entities': [(113, 138, 'triggers my rapid cycling')]}),
#  ('@USER__ i think it was an anxiety meds dream. damn quetiapine.',
#   {'entities': [(41, 46, 'dream')]}),
#  ('@USER__ quetiapine. very low dose even with increase. helps me get to sleep (&amp; eat in general) but feel really groggy in the morning',
#   {'entities': [(122, 143, 'groggy in the morning')]}),
#  ('03.00 day 19 rivaroxaban diary. just taken 2 paracetamol. probabably will take 70 minutes to work. a long painful night ahead.',
#   {'entities': [(106, 113, 'painful')]}),
#  ('your humira shot burns with the power of a thousand suns ibdfmlmoments crohns ibd uc',
#   {'entities': [(17, 22, 'burns')]}),
#  ('today is the day for my biweekly humira injection, any volunteers to take it for me?  it hus.',
#   {'entities': [(90, 95, 'hurts')]}),
#  ("new dx: dysthymia. sta seroquel (which i've had before. it zombified me iirc).",
#   {'entities': [(61, 70, 'zombified')]}),
#  ("@USER__ depakote made me feel flat, but helps many. zyprexa can cause weight gain, so be very careful. i can't tolerate it.",
#   {'entities': [(78, 89, 'weight gain')]}),
#  ('takin anbien &amp;seroquel for bad insomnia gives u messed up dreams doc saids its normal',
#   {'entities': [(52, 68, 'messed up dreams')]}),
#  ('been on humira now sho period 4 to 6 injections no noticeable change in pain but racing hea and palpitations. mtx at 1ml injection.',
#   {'entities': [(83, 95, 'racing heart')]}),
#  ('been on humira now sho period 4 to 6 injections no noticeable change in pain but racing hea and palpitations. mtx at 1ml injection.',
#   {'entities': [(100, 112, 'palpitations')]}),
#  ('hey not sleeping. hotflashes menopause effexor',
#   {'entities': [(4, 16, 'not sleeping')]}),
#  ('@USER__ i think it?s an snri, i?m not even sure. it?s viibryd. but none of my anti-depressants have ever messed me up like this before',
#   {'entities': [(112, 124, 'messed me up')]}),
#  ('19.32 day 20 rivaroxaban diary. still residual aches and pains; only had 4 paracetamol today.',
#   {'entities': [(47, 52, 'aches')]}),
#  ('19.32 day 20 rivaroxaban diary. still residual aches and pains; only had 4 paracetamol today.',
#   {'entities': [(57, 62, 'pains')]}),
#  ('i better go to bed.. effexor withdrawal makes me feel kinda terrible ugh.',
#   {'entities': [(49, 68, 'feel kinda terrible')]}),
#  ('i better go to bed.. effexor withdrawal makes me feel kinda terrible ugh.',
#   {'entities': [(29, 39, 'withdrawal')]}),
#  ('@USER__ i was on quetiapine and gained 40lbs wall&gt; so i am not even trying olanzapine. they gave me abilify cause it not supposed to',
#   {'entities': [(39, 51, 'gained 40lbs')]}),
#  ("@USER__ i 'served' 6months of fluoxetine-time around 18 years ago, it put a smile on my face but inside i was still screaming. ",
#   {'entities': [(103, 131, 'inside i was still screaming')]}),
#  ('@USER__ @USER__ what i take is serious. i never was informed ahead of time. i could get "metabolic" syndrome from seroquel.',
#   {'entities': [(99, 121, 'metabolic"" syndrome')]}),
#  ('half of seroquel knocks me out so fast and im asleep for at least 10 hours...',
#   {'entities': [(17, 30, 'knocks me out')]}),
#  ('08.55 day 21 rivaroxaban diary strange muscle spasms especially in neck shoulders and legs. no more fluid retention. more mobile.',
#   {'entities': [(100, 115, 'fluid retention')]}),
#  ('08.55 day 21 rivaroxaban diary strange muscle spasms especially in neck shoulders and legs. no more fluid retention. more mobile.',
#   {'entities': [(122, 128, 'mobile')]}),
#  ('08.55 day 21 rivaroxaban diary strange muscle spasms especially in neck shoulders and legs. no more fluid retention. more mobile.',
#   {'entities': [(39, 52, 'muscle spasms')]}),
#  ('epilepsy is sucktastic. neuro appt monday to discuss a third med after getting the rash with lamotrigine and the glaucoma with topiramate.',
#   {'entities': [(84, 88, 'Rash')]}),
#  ('epilepsy is sucktastic. neuro appt monday to discuss a third med after getting the rash with lamotrigine and the glaucoma with topiramate.',
#   {'entities': [(114, 122, 'Glaucoma')]}),
#  ('@USER__ i still get the pins &amp; needles feeling in my hands since doing humira',
#   {'entities': [(33, 51, 'pins &amp; needles')]}),
#  ('@USER__ @USER__ my step-dad was on effexer,taking supplements for energy and drinking like a fish when he shot my daughter&amp;me',
#   {'entities': [(120, 136, 'shot my daughter')]}),
#  ('this seroquel got me lo0o0py as helll.  this status took me at least thiy minutes to type i keep waking up without knowing i feel asleep',
#   {'entities': [(69, 91, 'thirty minutes to type')]}),
#  ('this seroquel got me lo0o0py as helll.  this status took me at least thiy minutes to type i keep waking up without knowing i feel asleep',
#   {'entities': [(21, 28, 'lo0o0py')]}),
#  ('this seroquel got me lo0o0py as helll.  this status took me at least thiy minutes to type i keep waking up without knowing i feel asleep',
#   {'entities': [(99, 138, 'waking up without knowing I feel asleep')]}),
#  ('rivaroxaban diary day 22. am beginning to think all pains from pressure on that pa of body are due to fluid retention.',
#   {'entities': [(104, 119, 'fluid retention')]}),
#  ('rivaroxaban diary day 22. am beginning to think all pains from pressure on that pa of body are due to fluid retention.',
#   {'entities': [(52, 57, 'pains')]}),
#  ("@USER__ natural don't work for me, try 300mg of seroquel...you'll sleep for days, i have insomnia that's what they give me lol",
#   {'entities': [(69, 83, 'sleep for days')]}),
#  ('doc for panic disorders: alprazolam (addictive) and paroxetine (sedating). psychiatry',
#   {'entities': [(37, 46, 'addictive')]}),
#  ('doc for panic disorders: alprazolam (addictive) and paroxetine (sedating). psychiatry',
#   {'entities': [(64, 72, 'sedating')]}),
#  ('@USER__ dude i feel physically and mentally drained.. thats the paxil i wanted hard at work',
#   {'entities': [(27, 37, 'physically')]}),
#  ('@USER__ dude i feel physically and mentally drained.. thats the paxil i wanted hard at work',
#   {'entities': [(42, 58, 'mentally drained')]}),
#  ('04.46 day 23 rivaroxaban diary. much better than yesterday. still neck, back, hip, and leg aches but not so intense.',
#   {'entities': [(73, 97, 'back, hip, and leg aches')]}),
#  ('04.46 day 23 rivaroxaban diary. much better than yesterday. still neck, back, hip, and leg aches but not so intense.',
#   {'entities': [(88, 97, 'leg aches')]}),
#  ('04.46 day 23 rivaroxaban diary. much better than yesterday. still neck, back, hip, and leg aches but not so intense.',
#   {'entities': [(67, 97, 'neck, back, hip, and leg aches')]}),
#  ('04.46 day 23 rivaroxaban diary. much better than yesterday. still neck, back, hip, and leg aches but not so intense.',
#   {'entities': [(79, 97, 'hip, and leg aches')]}),
#  ('@USER__ smh. lmao paxil was my first, i just stopped effexor (the headaches were a nightmare)',
#   {'entities': [(70, 80, 'headaches ')]}),
#  ("the toilet just flushed itself.  my apament is haunted.  paxil tells me it's common for apaments to be haunted.  send help",
#   {'entities': [(79, 114, 'common for apartments to be haunted')]}),
#  ("@USER__ i do have a crisis number, but i'm just going to knock myself out today w/ trazodone and sta antipsychotics today too.",
#   {'entities': [(110, 124, 'antipsychotics')]}),
#  ('wish it was monday...seeing doctor tomorrow &amp; want to see if he has any suggestions for my withdrawal. paroxetine anxiety fedup',
#   {'entities': [(95, 105, 'withdrawal')]}),
#  ("15.15 rivaroxaban diary day 24.  pains easing all the time. didn't take losaan yesterday. will get bp and hopefully inr checked today.",
#   {'entities': [(33, 38, 'Pains')]}),
#  ("feels like one of those 5-cup coffee days - but wait: i'm weaning off seroquel. aha!",
#   {'entities': [(0, 42, 'Feels like one of those 5-cup #coffee days')]}),
#  ('the most upsetting thing about silver linings playbook, is how bradley cooper can take seroquel and still stay in shape.',
#   {'entities': [(107, 120, 'stay in shape')]}),
#  ('then the viibryd it will be the hardest. makes you very ill. hospital ill.',
#   {'entities': [(70, 73, 'ill')]}),
#  ('effexor dreams, now with lucidity. i grant the power of flight?',
#   {'entities': [(26, 34, 'lucidity')]}),
#  ('@USER__ my dreams became vivider i think with effexor bpdchat',
#   {'entities': [(12, 33, 'dreams became vivider')]}),
#  ('bombed on olanzapine. work going to be tricky. 5 days of not drinking coming up. i could sleep all the time atm.',
#   {'entities': [(89, 107, 'sleep all the time')]}),
#  ('bombed on olanzapine. work going to be tricky. 5 days of not drinking coming up. i could sleep all the time atm.',
#   {'entities': [(0, 6, 'Bombed')]}),
#  ('@USER__ @USER__ i agree that the after sting is much worse from humira than enbrel rheum',
#   {'entities': [(42, 53, 'after sting')]}),
#  ("@USER__ @USER__ i couldn't take lamictal 1 week into it i got the rash.a rush trip to the er.6 months till rash was gone.",
#   {'entities': [(80, 84, 'rash')]}),
#  ("i didn't eect that going off of paxil would make me want to look at my farrah fawcett poster quite so much.",
#   {'entities': [(62, 94, 'look at my Farrah Fawcett poster')]}),
#  ('panic attacking because you cant find your effexor and know withdrawal will set in momentarily  .',
#   {'entities': [(60, 70, 'withdrawal')]}),
#  ("@USER__ i'm not even sure what to request.  seraline makes me sick now, venlafaxine made me sick, reboxetine and citalopram useless",
#   {'entities': [(70, 74, 'sick')]}),
#  ('question time crohns ibd humira does anyone suffer from egg burps? what works for you',
#   {'entities': [(59, 68, 'egg burps')]}),
#  ("i'm so fine today. increasing zyprexa,my condisition became so good. it has a side effect that increase my weight. i must care about it.",
#   {'entities': [(96, 114, 'increase my weight')]}),
#  ('@USER__ every time i forget seroquel, i end up rage breaking things eg- my laptop *facepalm*',
#   {'entities': [(47, 67, 'rage breaking things')]}),
#  ('being sick every morning is getting really old. not sure if anxiety or my body getting used to paxil.  anyone know?',
#   {'entities': [(6, 10, 'sick')]}),
#  ("i can't wait to go get my anti nauaea meds tonight. i feel like shit. humira is definitely kicking my ass but my skin lools great.",
#   {'entities': [(91, 105, 'kicking my ass')]}),
#  ("i can't wait to go get my anti nauaea meds tonight. i feel like shit. humira is definitely kicking my ass but my skin lools great.",
#   {'entities': [(31, 37, 'nauaea')]}),
#  (" @USER__: wtf? can't even get whipped cream out of the can? my arms just keep getting worse. damned cipro.",
#   {'entities': [(72, 101, 'arms just keep getting worse.')]}),
#  (" @USER__: wtf? can't even get whipped cream out of the can? my arms just keep getting worse. damned cipro.",
#   {'entities': [(24, 67, "can't even get whipped cream out of the can")]}),
#  ('@USER__ it helped me enormously with seroquel withdrawal but it makes benzo withdrawal much worse.',
#   {'entities': [(84, 94, 'withdrawal')]}),
#  ('whoah so dizzing.  damn   tamazapam - shld probably wap back to quetiapine if this keeps up! but it makes me feel so ick!',
#   {'entities': [(109, 120, 'feel so Ick')]}),
#  ("the seroquel the doc gave me, makes doing things difficult. . . but if i don't do something, i'll fall asleep. the catch-22 of crazy.",
#   {'entities': [(37, 59, 'doing things difficult')]}),
#  ("the seroquel the doc gave me, makes doing things difficult. . . but if i don't do something, i'll fall asleep. the catch-22 of crazy.",
#   {'entities': [(99, 110, 'fall asleep')]}),
#  ("@USER__ ffs!! i'm getting shooting pains down arms &amp; legs now &amp; in eve whole body ache humira is horrible ??",
#   {'entities': [(93, 102, 'body ache')]}),
#  ("@USER__ ffs!! i'm getting shooting pains down arms &amp; legs now &amp; in eve whole body ache humira is horrible ??",
#   {'entities': [(34, 58, 'shooting pains down arms')]}),
#  ("@USER__ ffs!! i'm getting shooting pains down arms &amp; legs now &amp; in eve whole body ache humira is horrible ??",
#   {'entities': [(34, 69, 'shooting pains down arms &amp; legs')]}),
#  ('screw you paxil! you do wonders for anxiety but you make me a ultra lightweight',
#   {'entities': [(68, 79, 'lightweight')]}),
#  ("the difference between 'just tired' and 'tired &amp; in a fog' is amazing.  so happy to be done taking levaquin, that stuff is way too strong",
#   {'entities': [(54, 62, 'in a fog')]}),
#  ("the difference between 'just tired' and 'tired &amp; in a fog' is amazing.  so happy to be done taking levaquin, that stuff is way too strong",
#   {'entities': [(42, 47, 'tired')]}),
#  ('@USER__ i dont get it, sex i mean. the doctors p[ut me on venlafaxin',
#   {'entities': [(14, 30, 'dont get it, sex')]}),
#  ("@USER__ i'm reducing duloxitine (been on 6 yr) and slowly increasing m but slept 13-14 hrs solid and still feel wasted",
#   {'entities': [(112, 123, 'feel wasted')]}),
#  ("@USER__ i'm reducing duloxitine (been on 6 yr) and slowly increasing m but slept 13-14 hrs solid and still feel wasted",
#   {'entities': [(80, 95, 'slept 13-14 hrs')]}),
#  ("did you know insanely intense dreams are a known side effect of venlafaxine? it's not an antidepressant, it's my dream fuel!",
#   {'entities': [(23, 37, 'intense dreams')]}),
#  ("@USER__ i've been taking venlafaxine since 2007, it's like hotel california - you can check in, but you can never leave.",
#   {'entities': [(82, 123, 'you can check in, but you can never leave')]}),
#  ("does cipro make anyone's else's brain turn to mush or am i actually just going crazy?",
#   {'entities': [(32, 50, 'brain turn to mush')]}),
#  (' @USER__: @USER__ does paxil withdrawal take! extremely emotional switched to wellbutrin. wanna crawl in a hole.',
#   {'entities': [(109, 124, 'crawl in a hole')]}),
#  (' @USER__: @USER__ does paxil withdrawal take! extremely emotional switched to wellbutrin. wanna crawl in a hole.',
#   {'entities': [(67, 76, 'emotional')]}),
#  (' @USER__: @USER__ does paxil withdrawal take! extremely emotional switched to wellbutrin. wanna crawl in a hole.',
#   {'entities': [(40, 50, 'withdrawal')]}),
#  (' @USER__: my journey into the dark night of the soul was launched by an adverse reaction to the drug effexor. taking this... http',
#   {'entities': [(40, 62, 'dark night of the soul')]}),
#  ("@USER__ i've had to reduce the quetiapine back to 400mg. couldn't take the increased gastro pain. was crumpled in a heap crying x",
#   {'entities': [(130, 136, 'crying')]}),
#  ("@USER__ i've had to reduce the quetiapine back to 400mg. couldn't take the increased gastro pain. was crumpled in a heap crying x",
#   {'entities': [(94, 105, 'gastro pain')]}),
#  ("dissociative fugues &amp; loss of empathy since age 11, serious cardio problems since age 14, almost dying of paxil withdrawal @ 21, that's a-ok",
#   {'entities': [(117, 127, 'withdrawal')]}),
#  ('so last night i kept waking up with period pain. took what i thought was ibuprofen 3 times. turned out to be seroquel. i just woke up.',
#   {'entities': [(121, 133, 'just woke up')]}),
#  ("abilify for 3 weeks has made me lose 1/6 of the weight i put on w/seroquel, and i've been eating like shit. i love you abilify!",
#   {'entities': [(49, 64, 'weight I put on')]}),
#  ('@USER__ paly true but olanzapine is the worst ever for inducing carb cravings for some unfounate ppl serequel and clozaril a 2nd',
#   {'entities': [(72, 86, ' carb cravings')]}),
#  ("gamma-aminobutyric acid+glycine aralyzing rem neurotransmittersrecisely when you shouldn't wake up=grumpy as fuck  sciencestrikesagain",
#   {'entities': [(85, 102, "shouldn't wake up")]}),
#  ("@USER__ fanapt was the only thing that calmed her rages but comes with tremors.   i'm so sorry ",
#   {'entities': [(78, 85, 'tremors')]}),
#  ("worked a double shift today while dealing with effexor withdrawals, i'm a tough bitch; fight me. badass sick withdraws sicksicksick",
#   {'entities': [(107, 111, 'sick')]}),
#  ("worked a double shift today while dealing with effexor withdrawals, i'm a tough bitch; fight me. badass sick withdraws sicksicksick",
#   {'entities': [(124, 136, 'sicksicksick')]}),
#  ("worked a double shift today while dealing with effexor withdrawals, i'm a tough bitch; fight me. badass sick withdraws sicksicksick",
#   {'entities': [(56, 67, 'withdrawals')]}),
#  ("worked a double shift today while dealing with effexor withdrawals, i'm a tough bitch; fight me. badass sick withdraws sicksicksick",
#   {'entities': [(113, 122, 'withdraws')]}),
#  ('2/2 blood tests scheduled. bp normal now have own coaguckek machine. still aches and pains, legs better. taking codeine rivaroxaban losaan',
#   {'entities': [(76, 81, 'aches')]}),
#  ('2/2 blood tests scheduled. bp normal now have own coaguckek machine. still aches and pains, legs better. taking codeine rivaroxaban losaan',
#   {'entities': [(86, 91, 'pains')]}),
#  ('@USER__ @USER__ sorry for jumping in. trying to get up for work after night seroquel is a nightmare!',
#   {'entities': [(54, 70, 'Trying to get up')]}),
#  ('@USER__  nope, i tested positive for jcv.?????? ????????jcv &amp; tysabri = permanent brain damage or sudden death.',
#   {'entities': [(41, 44, 'JCV')]}),
#  ('@USER__  nope, i tested positive for jcv.?????? ????????jcv &amp; tysabri = permanent brain damage or sudden death.',
#   {'entities': [(60, 63, 'JCV')]}),
#  ('oh. delayed reaction from humira injections-my hip joints just staed huing. haha.',
#   {'entities': [(47, 78, 'hip joints just started hurting')]}),
#  ('@USER__ that sucks. humira made me so sick. remicade helped a but, but then seizures put that out. now waiting, just prednisone now.',
#   {'entities': [(45, 49, 'sick')]}),
#  ('@USER__ that sucks. humira made me so sick. remicade helped a but, but then seizures put that out. now waiting, just prednisone now.',
#   {'entities': [(83, 91, 'seizures')]}),
#  ("i do baclofen which helps w incontinent urges but don't think it's good for the bowels. (very personal but wtf) anyone have insight for me??",
#   {'entities': [(80, 86, 'bowels')]}),
#  (' @USER__: @USER__ if this is a real question, withdrawal from an antidepressant named effexor was worse than cocaine withdrawal',
#   {'entities': [(126, 136, 'withdrawal')]}),
#  ('@USER__ @USER__ thinking it might be the baclofen doing it.only on a low dose though.broken sleep is a nightmare.msfatigue',
#   {'entities': [(97, 109, 'Broken sleep')]}),
#  ('oh hey. much like other anti-convulsants, lamictal dehydrates you. so much is elained.',
#   {'entities': [(52, 62, 'dehydrates')]}),
#  ('@USER__ olanzapine is another anti-psychotic medication. it works on my bipolar but makes me binge eat',
#   {'entities': [(96, 105, 'binge eat')]}),
#  ('i used to be on paxil but that made me more depressed and prozac made me angry',
#   {'entities': [(73, 78, 'angry')]}),
#  ('i used to be on paxil but that made me more depressed and prozac made me angry',
#   {'entities': [(44, 53, 'depressed')]}),
#  ("@USER__ humira helped my crohns but then respiratory issues ensued &amp; now i can't take anything &amp; have major lung issues",
#   {'entities': [(127, 138, 'lung issues')]}),
#  ("@USER__ humira helped my crohns but then respiratory issues ensued &amp; now i can't take anything &amp; have major lung issues",
#   {'entities': [(52, 70, 'Respiratory issues')]}),
#  ('when i had my infected k stone, hospital put me on cipro - a synthetic antibiotic. i "smelled" a pungent solvent odor, i smell it now. why?',
#   {'entities': [(124, 129, 'smell')]}),
#  ('when i had my infected k stone, hospital put me on cipro - a synthetic antibiotic. i "smelled" a pungent solvent odor, i smell it now. why?',
#   {'entities': [(86, 120, 'smelled"" a pungent solvent odor')]}),
#  ('@USER__ hcsm i sta chemo on tues b/c of humira so i know.  it helped but it then destroyed my lungs.',
#   {'entities': [(26, 31, 'Chemo')]}),
#  ('@USER__ hcsm i sta chemo on tues b/c of humira so i know.  it helped but it then destroyed my lungs.',
#   {'entities': [(89, 107, 'destroyed my lungs')]}),
#  ('bedtime. hopefully  the headache and nausea from the levaquin will be gone leaving me with only the more common side effects of antibiotics.',
#   {'entities': [(24, 32, 'headache')]}),
#  ('bedtime. hopefully  the headache and nausea from the levaquin will be gone leaving me with only the more common side effects of antibiotics.',
#   {'entities': [(37, 43, 'nausea')]}),
# ...
#  ('question: recently i have been hyper-sensitive to different textures, does anyone know if this is a bipolar / lamotrigine thing??',
#   {'entities': [(32, 47, 'hyper-sensitive')]}),
#  ('bloody dreadful nights sleep= joint pain. combination of sitting all day in training and full therapeutic dose of lamotrigine',
#   {'entities': [(30, 40, 'joint pain')]}),
#  ('bloody dreadful nights sleep= joint pain. combination of sitting all day in training and full therapeutic dose of lamotrigine',
#   {'entities': [(7, 28, 'dreadful nights sleep')]}),
#  ("i've decided i'm really not happy with the pain lamotrigine is causing or the poor sleep. i am thinking of asking for a trial of prozac and",
#   {'entities': [(43, 47, 'pain')]}),
#  ("i've decided i'm really not happy with the pain lamotrigine is causing or the poor sleep. i am thinking of asking for a trial of prozac and",
#   {'entities': [(78, 88, 'poor sleep')]}),
#  ("@USER__ the misery i'm eeriencing today from the pain, outweighs the anti-depressant effect of the lamotrigine",
#   {'entities': [(60, 64, 'pain')]}),
#  ('me : feeling fine, watching tv ... swiffer commercial lamotrigine : lol lets make the bitch cry at this... a fucking swiffer commercial.',
#   {'entities': [(94, 98, 'cry ')]}),
#  ('lamotrigine headaches suck  i wanna curl up &amp; cry.',
#   {'entities': [(13, 22, 'headaches')]}),
#  ('not feeling like staying up all night, so taking the levothyroxin in the morning. lamotrigine early at 0432utc',
#   {'entities': [(18, 38, 'staying up all night')]}),
#  ('@USER__ yeah i hear epilim is pretty tough, sorry to hear re bad times with it  oddly, dear sweet lamotrigine tipped me to a dark place',
#   {'entities': [(115, 140, 'tipped me to a dark place')]}),
#  ('@USER__ @USER__ was on lamotrigine for about 5 months, got taken off them due to a rash on my elbow  now i feel more meh',
#   {'entities': [(95, 99, 'rash')]}),
#  ('allergic reaction to lamotrigine. feel free to share &amp; distribute. kill bigpharma before it kills us. ',
#   {'entities': [(0, 17, 'Allergic reaction')]}),
#  ('allergic reaction to lamotrigine. feel free to share &amp; distribute. kill bigpharma before it kills us. ',
#   {'entities': [(0, 17, 'Allergic reaction')]}),
#  ('allergic reaction to lamotrigine. feel free to share &amp; distribute. kill bigpharma before it kills us. ',
#   {'entities': [(0, 17, 'Allergic reaction')]}),
#  ('allergic reaction to lamotrigine. feel free to share &amp; distribute. kill bigpharma before it kills us. ',
#   {'entities': [(0, 17, 'Allergic reaction')]}),
#  ('allergic reaction to lamotrigine. feel free to share &amp; distribute. kill bigpharma before it kills us. ',
#   {'entities': [(0, 17, 'Allergic reaction')]}),
#  ('oh, and i forgot that with lamotrigine come awful night terrors. i woke up no fewer than five times screaming and sweaty. lol',
#   {'entities': [(51, 64, 'night terrors')]}),
#  ("i think the lamotrigine is finally doing what it's supposed to; which is not make me sick, but keep my moods stable  yaay 3",
#   {'entities': [(86, 90, 'sick')]}),
#  ("ain't nothing worse than having vasovagal pre-syncope from levaquin toxicity. hard to digest food just pushes all the nerves. blah",
#   {'entities': [(78, 92, 'Hard to digest')]}),
#  ("ain't nothing worse than having vasovagal pre-syncope from levaquin toxicity. hard to digest food just pushes all the nerves. blah",
#   {'entities': [(68, 76, 'toxicity')]}),
#  ("ain't nothing worse than having vasovagal pre-syncope from levaquin toxicity. hard to digest food just pushes all the nerves. blah",
#   {'entities': [(32, 53, 'vasovagal pre-syncope')]}),
#  ("not that anyone noticed, but my ambienwithdrawl only lasted a few days. why? because i got another scrip. i need it while i'm on levaquin.",
#   {'entities': [(40, 49, 'withdrawl')]}),
#  ('is it possible for levaquin to cause massive pain in my joints? medicalquery',
#   {'entities': [(45, 62, 'pain in my joints')]}),
#  ('@USER__ i cannot be in the sun! levaquin',
#   {'entities': [(16, 36, 'cannot be in the sun')]}),
#  (' @USER__: @USER__ i cannot be in the sun! levaquin',
#   {'entities': [(35, 55, 'cannot be in the sun')]}),
#  ('levaquin sucks. blinding headaches. vomiting. diarrhea.   time for my next dose.  happy weekend.   tmi fml',
#   {'entities': [(46, 54, 'Diarrhea')]}),
#  ('levaquin sucks. blinding headaches. vomiting. diarrhea.   time for my next dose.  happy weekend.   tmi fml',
#   {'entities': [(25, 34, 'headaches')]}),
#  ('levaquin sucks. blinding headaches. vomiting. diarrhea.   time for my next dose.  happy weekend.   tmi fml',
#   {'entities': [(36, 44, 'Vomiting')]}),
#  ('note to self - nicotine lozenge &amp; alcohol = nausea.',
#   {'entities': [(48, 54, 'nausea')]}),
#  ('i have a lozenge i cant feel my throat',
#   {'entities': [(19, 38, 'CANT FEEL MY THROAT')]}),
#  ("popped a zinc lozenge, i'm sweatin", {'entities': [(28, 35, 'sweatin')]}),
#  ('you guys i was sucking on this lozenge thats supposed to numb sore throats and now i cant feel my mouth',
#   {'entities': [(85, 103, 'CANT FEEL MY MOUTH')]}),
#  ('it appears that my twitter addiction may have just been a side effect of my nicotine lozenge addiction.',
#   {'entities': [(93, 102, 'addiction')]}),
#  (' @USER__: it appears that my twitter addiction may have just been a side effect of my nicotine lozenge addiction.',
#   {'entities': [(112, 121, 'addiction')]}),
#  (' @USER__: it appears that my twitter addiction may have just been a side effect of my nicotine lozenge addiction.',
#   {'entities': [(112, 121, 'addiction')]}),
#  ('so i may be allergic to the metoprolol. rash on my face. needing my inhaler daily since friday.',
#   {'entities': [(12, 20, 'allergic')]}),
#  ('so i may be allergic to the metoprolol. rash on my face. needing my inhaler daily since friday.',
#   {'entities': [(57, 75, 'Needing my inhaler')]}),
#  ('so i may be allergic to the metoprolol. rash on my face. needing my inhaler daily since friday.',
#   {'entities': [(40, 45, 'Rash ')]}),
#  ("i'm gonna make a list of drugs that give you mad crazy dreams. trazadone and metoprolol are at the top.",
#   {'entities': [(49, 61, 'crazy dreams')]}),
#  ("okay, this metoprolol is not a game. aside from the occasional chest pain when i breathe, i'm fine. ?",
#   {'entities': [(64, 74, 'chest pain')]}),
#  ('nicotine headache! notcool', {'entities': [(9, 17, 'headache')]}),
#  ('@USER__ very little is going to get in the way of their nicotine addiction.',
#   {'entities': [(72, 81, 'addiction')]}),
#  ('holy shit i quit. no for real this time tho. fuck that noise. aint got time for stuffy sinuses and nicotine addiction.',
#   {'entities': [(108, 117, 'addiction')]}),
#  ('holy shit i quit. no for real this time tho. fuck that noise. aint got time for stuffy sinuses and nicotine addiction.',
#   {'entities': [(80, 94, 'stuffy sinuses')]}),
#  ('fucking nicotine driving my fucking mind up the fucking wall. i feel like kathy bates',
#   {'entities': [(17, 60, 'DRIVING MY FUCKING MIND UP THE FUCKING WALL')]}),
#  ("i'm never gonna pack it in i know i'm addicted to the nicotine through my veins it flow",
#   {'entities': [(38, 46, 'addicted')]}),
#  ('do the people that make the blu e-cig not fucking understand what addiction to nicotine is?! where is it already',
#   {'entities': [(66, 75, 'addiction')]}),
#  ('i can go without nicotine for a few day but by the time the third day comes around i want to rip out my teeth',
#   {'entities': [(93, 109, 'rip out my teeth')]}),
#  ('brb, dying of nicotine withdrawal.',
#   {'entities': [(24, 34, 'withdrawal')]}),
#  ('@USER__ i cant sleep im having a well bad nicotine craving',
#   {'entities': [(60, 67, 'craving')]}),
#  ('@USER__ i cant sleep im having a well bad nicotine craving',
#   {'entities': [(19, 29, 'cant sleep')]}),
#  ('going through a real bad nicotine withdraw...',
#   {'entities': [(34, 42, 'withdraw')]}),
#  ('nicotine withdrawals. needasmoke', {'entities': [(9, 20, 'withdrawals')]}),
#  ('this new baccy is just making my cough so much worse but ahhh well need my nicotine',
#   {'entities': [(33, 38, 'cough')]}),
#  ("bought ourselves an electronic cigarette for fun and now i think we're addicted to nicotine ???",
#   {'entities': [(71, 79, 'addicted')]}),
#  ("@USER__ it's my nicotine withdrawls",
#   {'entities': [(27, 38, ' withdrawls')]}),
#  ('fuck here comes the nicotine cravings damn you hookah',
#   {'entities': [(29, 37, 'CRAVINGS')]}),
#  ('nicotine withdrawal is hitting me so fuckin hard right now',
#   {'entities': [(9, 19, 'withdrawal')]}),
#  ('officially addicted to nicotine', {'entities': [(11, 19, 'addicted')]}),
#  ('all this nicotine is going to my head',
#   {'entities': [(21, 37, 'going to my head')]}),
#  ('addicted to nicotine badly.', {'entities': [(0, 8, 'addicted')]}),
#  ('nicotine withdrawals 2daysdown foreveogo headache irritable toomanyhashtags makeitstop',
#   {'entities': [(46, 54, 'headache')]}),
#  ('nicotine withdrawals 2daysdown foreveogo headache irritable toomanyhashtags makeitstop',
#   {'entities': [(56, 65, 'irritable')]}),
#  ('nicotine withdrawals 2daysdown foreveogo headache irritable toomanyhashtags makeitstop',
#   {'entities': [(9, 20, 'withdrawals')]}),
#  ('do you know how badly i want a cigarette right now? but no. i manfully suffer through nicotine withdrawal?all for you sacrifice',
#   {'entities': [(94, 105, ' withdrawal')]}),
#  ("i'm void of nicotine and my moods are void of stability.",
#   {'entities': [(28, 55, 'moods are void of stability')]}),
#  ('@USER__ had a migraine, asked him for medicine, he\'s sitting there like "that\'s what you get! nicotine withdrawals!" like fuck dad.',
#   {'entities': [(19, 27, 'migraine')]}),
#  ('@USER__ had a migraine, asked him for medicine, he\'s sitting there like "that\'s what you get! nicotine withdrawals!" like fuck dad.',
#   {'entities': [(109, 120, 'withdrawals')]}),
#  ('day 2 without nicotine: fuck sleep would be nice. so would a dip.......',
#   {'entities': [(29, 34, 'sleep')]}),
#  ('sent my lovely compandre to fuel my nicotine addiction',
#   {'entities': [(45, 54, 'addiction')]}),
#  ("pop a ciprofloxacin i'm sweating woo!",
#   {'entities': [(24, 32, 'sweating')]}),
#  ("@USER__ the only things i know i'm allergic to are sulfa drugs and ciprofloxacin.",
#   {'entities': [(37, 45, 'allergic')]}),
#  ('when the depression is coming out caused by this damn levofloxacin )',
#   {'entities': [(9, 19, 'depression')]}),
#  ('rocephin  ciprofloxacin = me barely able to stay awake',
#   {'entities': [(29, 54, 'barely able to stay awake')]}),
#  ('my battle continues with olanzapine weight gain with a bowl of porridge and a 9am bootcamp iwillwin',
#   {'entities': [(36, 47, 'weight gain')]}),
#  ("i can't secretly try and come off my olanzapine as my cpn and psychiatrist will notice the weight loss!",
#   {'entities': [(91, 97, 'weight')]}),
#  ('@USER__ yeah the first time i was on olanzapine i did not put much weight on but 2nd time i did! weird!',
#   {'entities': [(64, 82, 'put much weight on')]}),
#  ('have run out of olanzapine, was tapering off anyway but this is a bit too quick-feel restless. hot bath and diazepam time ',
#   {'entities': [(86, 94, 'restless')]}),
#  ('ok brain &amp; body. we need a chat about oversleeping and overeating since taking olanzapine again tuboficecream timetochange junkfood gym',
#   {'entities': [(59, 69, 'overeating')]}),
#  ('ok brain &amp; body. we need a chat about oversleeping and overeating since taking olanzapine again tuboficecream timetochange junkfood gym',
#   {'entities': [(42, 54, 'oversleeping')]}),
#  ('despite a difficult meeting with hr today i feel good, i feel chilled, i feel happy but i still feel fat! olanzapine',
#   {'entities': [(102, 105, 'fat')]}),
#  ('only problem is the ride has fuelled the olanzapine munchies. i was a nightmare in the supermarket tonight!',
#   {'entities': [(52, 60, 'munchies')]}),
#  ('gave in wholeheaedly today to my olanzapine munchies. had already had an ice cream and milkshake before this  ',
#   {'entities': [(46, 54, 'munchies')]}),
#  ('@USER__ i have been on amisulpride but only for a few days, i could not tolerate nausea and akathisia, olanzapine i can cope with',
#   {'entities': [(101, 110, 'akathisia')]}),
#  ('@USER__ i have been on amisulpride but only for a few days, i could not tolerate nausea and akathisia, olanzapine i can cope with',
#   {'entities': [(90, 96, 'nausea')]}),
#  ('had a great few hours on my bike but exercise drives my olanzapine munchies. getting fed up with not being able to fit into summer wardrobe',
#   {'entities': [(68, 76, 'munchies')]}),
#  ('had a great few hours on my bike but exercise drives my olanzapine munchies. getting fed up with not being able to fit into summer wardrobe',
#   {'entities': [(98, 140, 'not being able to fit into summer wardrobe')]}),
#  ("@USER__ olanzapine actually makes you put on weight, even when you aren't eating that much",
#   {'entities': [(41, 54, 'put on weight')]}),
#  ('does anyone know if the weight gain is less in olanzapine combined with prozac(symbyax) than in olanzapine alone?',
#   {'entities': [(25, 36, 'weight gain')]}),
#  ('thanks to all my re-tweeters, your suppo is very much appreciated. i took the full dosd of olanzapine last night sluggish',
#   {'entities': [(117, 125, 'sluggish')]}),
#  ('going off of olanzapine is no picnic.  you have to be prepared to ask the aid of the gods, jesus, krishna.',
#   {'entities': [(1, 37, 'going off of olanzapine is no picnic')]}),
#  ('@USER__ olanzapine. i was taking 7.5mg and that was a nightmare, now taking 5mg but the weight still keeps coming ',
#   {'entities': [(97, 122, 'weight still keeps coming')]}),
#  ("racing next sun so thought i'd better try on my tri suit. so depressing, can just about get into it and look like a whale ffs!! olanzapine",
#   {'entities': [(105, 122, 'look like a whale')]}),
#  ("@USER__ i'm sure it helps that you are so active. i did eventually lose my olanzapine lbs, so there is hope. ",
#   {'entities': [(84, 98, 'olanzapine lbs')]}),
#  ('gonna have to speak with my psychiatrist about stopping my olanzapine its interfering with my visions and it gives you memory loss and more.',
#   {'entities': [(119, 130, 'memory loss')]}),
#  ('gonna have to speak with my psychiatrist about stopping my olanzapine its interfering with my visions and it gives you memory loss and more.',
#   {'entities': [(74, 101, 'interfering with my visions')]}),
#  ('@USER__ first two weeks of olanzapine v drowsy. weight gain was an issue. great for my anxiety though.',
#   {'entities': [(41, 47, 'drowsy')]}),
#  ('@USER__ first two weeks of olanzapine v drowsy. weight gain was an issue. great for my anxiety though.',
#   {'entities': [(49, 60, 'weight gain')]}),
#  ('@USER__ i tried coming off my olanzapine twice in the past 3 years without telling my psych - unfounately too difficult to come off!',
#   {'entities': [(118, 139, 'difficult to come off')]}),
#  ("i'm now back on the olanzapine along side lithium. ugh. helloweightgain",
#   {'entities': [(62, 72, 'weightgain')]}),
#  ('@USER__ @USER__ recent spell in hospital and olanzapine sloth/weight gain',
#   {'entities': [(71, 76, 'sloth')]}),
#  ('@USER__ @USER__ recent spell in hospital and olanzapine sloth/weight gain',
#   {'entities': [(77, 88, 'weight gain')]}),
#  ('day has been a right off. missed opticians&amp;slept aw day. sitting here torn faced, wi greasy hair&amp;unwashed. swollen feet thx to olanzapine.',
#   {'entities': [(48, 60, 'slept aw day')]}),
#  ('day has been a right off. missed opticians&amp;slept aw day. sitting here torn faced, wi greasy hair&amp;unwashed. swollen feet thx to olanzapine.',
#   {'entities': [(75, 85, 'torn faced')]}),
#  ('day has been a right off. missed opticians&amp;slept aw day. sitting here torn faced, wi greasy hair&amp;unwashed. swollen feet thx to olanzapine.',
#   {'entities': [(116, 128, 'Swollen feet')]}),
#  ("@USER__ saying that, the whole reason i gained weight in the first place was due to the drug olanzapine. doctor's fault. ah well.",
#   {'entities': [(43, 56, 'gained weight')]}),
#  ('@USER__ ugh the olanzapine makes me so tired ',
#   {'entities': [(47, 52, 'tired')]}),
#  ('@USER__ ugh the olanzapine makes me so tired ',
#   {'entities': [(47, 52, 'tired')]}),
#  ...]
