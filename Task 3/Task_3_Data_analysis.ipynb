# %% [markdown]
# <a href="https://colab.research.google.com/github/roshanvkhatri/NLP-Social-Media-Mining-for-Health-Monitoring/blob/experimental/Task%203/Task_3_Data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import re
# import demoji
# import tensorflow as tf
# import tensorflow_hub as hub
# import tensorflow_text as text

# %%
df = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/NLP-Social-Media-Mining-for-Health-Monitoring/datasets/Task 3/train.tsv', sep = '\t')
df_train_val = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/NLP-Social-Media-Mining-for-Health-Monitoring/datasets/Task 3/train_valid.tsv', sep = '\t')
df_val = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/NLP-Social-Media-Mining-for-Health-Monitoring/datasets/Task 3/valid.tsv', sep = '\t')
df
# Out:
#       tweet_id  ...                label
# 0        13729  ...    Lit-News_mentions
# 1        12399  ...    Lit-News_mentions
# 2        20056  ...  Nonpersonal_reports
# 3        10175  ...    Lit-News_mentions
# 4        12179  ...    Lit-News_mentions
# ...        ...  ...                  ...
# 9062     22452  ...  Nonpersonal_reports
# 9063     11628  ...    Lit-News_mentions
# 9064     22372  ...  Nonpersonal_reports
# 9065     22329  ...  Nonpersonal_reports
# 9066     31246  ...         Self_reports
#
# [9067 rows x 3 columns]

# %%
df_LNM = df[df['label'] == "Lit-News_mentions"]
df_NPR = df[df['label'] == "Nonpersonal_reports"]
df_SR = df[df['label'] == "Self_reports"]
df_SR
# Out:
#       tweet_id                                              tweet         label
# 5        30823  I’ve had 4 waves of symptoms over 7 weeks. No ...  Self_reports
# 13       31218  Hubby had breathing issues and chest burning u...  Self_reports
# 17       30070  I am not scared of the symptoms I have right n...  Self_reports
# 21       30201  Waiting on our test kits to arrive but looks l...  Self_reports
# 41       30251  Officially sick of #longtailcovid now. I’ve be...  Self_reports
# ...        ...                                                ...           ...
# 9026     30971  It's really annoying because I rarely get ill ...  Self_reports
# 9030     30373  It did. I had 3 straight days of constant ches...  Self_reports
# 9039     30028  Okay. Vomiting. Temp 32.7°c cold sweats #LongC...  Self_reports
# 9060     30086  If anyone wants to know how coronavirus is tre...  Self_reports
# 9066     31246  "She then again tried to end the call and want...  Self_reports
#
# ...
